# %%
#Final Project 
import requests
import json 
import pandas as pd

def airspaces_lookup(location):
    if location != 'Quit':
        url = 'http://maps.googleapis.com/maps/api/geocode/json'
        options = { 'address' : location } 
        response = requests.get(url, params = options)            
        geodata = response.json()
        coords = geodata['results'][0]['geometry']['location']
        lat = coords['lat']
        lng = coords['lng']
    # airmap/
        query = {
            'latitude': lat,
            'longitude': lng,
        }
        headers = {
            'X-API-Key':  'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..XbRK4KtTev61yyr7Ed6kIWjBz1vMjxT1m2u8ormBmHI'
        }
        r = requests.get('https://api.airmap.com/status/v2/point', params = query, headers = headers);
        data = r.json()

        count = 0 
        advisories_list = data['data']['advisories']
        location_list = []
        advisory_list = []
        loc_type_list = []
        lat_list = []
        lon_list = []
        ven_list = []
        strt_list = []

        for i in advisories_list:
            location = data['data']['advisories'][count]['name']
            location_list.append(location)
            advisory = data['data']['advisories'][count]['color'] 
            advisory_list.append(advisory)
            loc_type = data['data']['advisories'][count]['type']
            loc_type_list.append(loc_type)
            lat = data['data']['advisories'][count]['latitude']
            lat_list.append(lat)
            lon = data['data']['advisories'][count]['longitude']
            lon_list.append(lon)
            count = count + 1 
            airspace_data = pd.DataFrame({'location' : location_list, 'advisory' : advisory_list, 'type' : loc_type_list,
                                         'latitude' : lat_list, 'longitude' : lon_list})
        return print(airspace_data)

#airmap end

def weather_location_lookup(location):
    if location != 'Quit':
        url = 'http://maps.googleapis.com/maps/api/geocode/json'
        options = { 'address' : location } 
        response = requests.get(url, params = options)            
        geodata = response.json()
        coords = geodata['results'][0]['geometry']['location']
        lat = coords['lat']
        lng = coords['lng']
        key = '5c74b6ce9cfe03b4e8780a360b5b6115'
        url = 'https://api.darksky.net/forecast/%s/%s,%s' % (key,lat,lng)
        response = requests.get(url)
        weather_data = response.json()
        conditions = weather_data['currently']['icon']  
        results = print('The current weather conditions for %s is "%s"' % (location,conditions))
        return results

#MAIN PROGRAM: START
    
print("Current Weather")

location = 0 
while True:
    if location != 'Quit':
        location = input("Enter a location: ").title()
        weather_location_lookup(location)
        print('\n')
        airspaces_lookup(location)
    elif location == 'Quit':
        break
# Out:
# Current Weather
# Enter a location: syracuse ny
# The current weather conditions for Syracuse Ny is "partly-cloudy-day"
#
#
#   advisory   latitude                               location  longitude  \
# 0   yellow  43.111341  SYRACUSE HANCOCK INTL AIRPORT CLASS C -76.106307
# 1   yellow  43.046159         Onondaga County Justice Center -76.146513
# 2   yellow  43.042322    UPSTATE MEDICAL UNIVERSITY HOSPITAL -76.139362
# 3   yellow  43.042322    UPSTATE MEDICAL UNIVERSITY HOSPITAL -76.139362
# 4    green  43.111194                  SYRACUSE HANCOCK INTL -76.106306
#
#                   type
# 0  controlled_airspace
# 1               prison
# 2             heliport
# 3             heliport
# 4              airport
# Enter a location: san fransisco
# The current weather conditions for San Fransisco is "partly-cloudy-day"
#
#
#   advisory   latitude                            location   longitude  \
# 0   yellow  37.775092                     HALL OF JUSTICE -122.404278
# ...

# %%
#airmap notes
import pandas as pd

def airspaces_lookup(location): 
    
     url = 'http://maps.googleapis.com/maps/api/geocode/json'
        options = { 'address' : location } 
        response = requests.get(url, params = options)            
        geodata = response.json()
        coords = geodata['results'][0]['geometry']['location']
        lat = coords['lat']
        lng = coords['lng']

    query = {
        'latitude': lat,
        'longitude': lng,
    }

    headers = {
        'X-API-Key':  'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..XbRK4KtTev61yyr7Ed6kIWjBz1vMjxT1m2u8ormBmHI'
    }

    r = requests.get('https://api.airmap.com/status/v2/point', params = query, headers = headers);
    data = r.json()
    
    count = 0 
    advisories_list = data['data']['advisories']
    location_list = []
    advisory_list = []
    loc_type_list = []
    lat_list = []
    lon_list = []
    ven_list = []
    strt_list = []

    for i in advisories_list:
        location = data['data']['advisories'][count]['name']
        location_list.append(location)
        advisory = data['data']['advisories'][count]['color'] 
        advisory_list.append(advisory)
        loc_type = data['data']['advisories'][count]['type']
        loc_type_list.append(loc_type)
        lat = data['data']['advisories'][count]['latitude']
        lat_list.append(lat)
        lon = data['data']['advisories'][count]['longitude']
        lon_list.append(lon)
        count = count + 1 


    airspace_data = pd.DataFrame({'location' : location_list, 'advisory' : advisory_list, 'type' : loc_type_list,
                                     'latitude' : lat_list, 'longitude' : lon_list})
    airspace_data
# Out:
#   advisory   latitude                            location   longitude  \
# 0   yellow  37.775092                     HALL OF JUSTICE -122.404278
# 1    green  37.778535                   Giants vs. Padres -122.389483
# 2    green  37.778535                  Giants vs. Dodgers -122.389483
# 3    green  37.778535                  Giants vs. Dodgers -122.389483
# 4    green  37.778535                  Giants vs. Dodgers -122.389483
# 5    green  37.778535                  Giants vs. Dodgers -122.389483
# 6   yellow  37.765776  UCSF MEDICAL CENTER AT MISSION BAY -122.390358
# 7   yellow  37.825923                            ALCATRAZ -122.421469
# 8    green  37.783519     SAN FRANCISCO VA MEDICAL CENTER -122.506789
#
#        type
# 0  heliport
# 1       tfr
# 2       tfr
# 3       tfr
# 4       tfr
# 5       tfr
# 6  heliport
# 7  heliport
# 8  heliport

# %%
#Note1 

count = 0 
advisories_list = data['data']['advisories']
for i in advisories_list:
    print(count)
    count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#Note2 - for sports events 

ven = data['data']['advisories'][count]['venue_name']
ven_list.append(ven)
start_time = data['data']['advisories'][count]['effective_start']
strt_list.append(start_time)
# Out:
# 0
